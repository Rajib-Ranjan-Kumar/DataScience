# %%
import pandas as pd
df=pd.read_csv('ee.csv')
df.head(5)
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK   2600             -         124           50.0
# 1  SH_CLERK   2600             -         124           50.0
# 2   AD_ASST   4400             -         101           10.0
# 3    MK_MAN  13000             -         100           20.0
# 4    MK_REP   6000             -         201           20.0

# %%
df.tail(5)
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 45          136      Hazel       NaN  HPHILTAN  650.127.1634  06-FEB-08
# 46          137     Renske    Ladwig   RLADWIG  650.121.1234  14-JUL-03
# 47          138    Stephen    Stiles   SSTILES  650.121.2034  26-OCT-05
# 48          139       John       Seo      JSEO  650.121.2019  12-FEB-06
# 49          140        NaN     Patel    JPATEL  650.121.1834  06-APR-06
#
#       JOB_ID SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 45  ST_CLERK   2200             -         122           50.0
# 46  ST_CLERK   3600             -         123           50.0
# 47  ST_CLERK   3200             -         NaN           50.0
# 48  ST_CLERK   2700             -         123           50.0
# 49  ST_CLERK   2500             -         123           50.0

# %%
df.describe()
# Out:
#        EMPLOYEE_ID  DEPARTMENT_ID
# count    50.000000      48.000000
# mean    134.760000      57.083333
# std      33.631594      25.176681
# min     100.000000      10.000000
# 25%     112.250000      50.000000
# 50%     124.500000      50.000000
# 75%     136.750000      60.000000
# max     206.000000     110.000000

# %%
df.dtypes
# Out:
# EMPLOYEE_ID         int64
# FIRST_NAME         object
# LAST_NAME          object
# EMAIL              object
# PHONE_NUMBER       object
# HIRE_DATE          object
# JOB_ID             object
# SALARY             object
# COMMISSION_PCT     object
# MANAGER_ID         object
# DEPARTMENT_ID     float64
# dtype: object

# %%
df.isnull()
# Out:
#     EMPLOYEE_ID  FIRST_NAME  LAST_NAME  EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0         False       False      False  False         False      False
# 1         False       False      False  False         False      False
# 2         False       False      False  False         False      False
# 3         False       False      False  False         False      False
# 4         False       False      False  False         False      False
# 5         False       False      False  False         False      False
# 6         False       False      False  False         False      False
# 7         False       False      False  False         False      False
# 8         False       False      False  False         False      False
# 9         False       False      False  False         False      False
# 10        False        True       True  False         False      False
# 11        False       False      False  False         False      False
# ...

# %%
df.isnull().any(axis=1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45     True
# 46    False
# 47     True
# 48    False
# 49     True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# EMPLOYEE_ID       0
# FIRST_NAME        2
# LAST_NAME         4
# EMAIL             0
# PHONE_NUMBER      1
# HIRE_DATE         0
# JOB_ID            0
# SALARY            0
# COMMISSION_PCT    0
# MANAGER_ID        1
# DEPARTMENT_ID     2
# dtype: int64

# %%
df.fillna(0)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME         EMAIL  PHONE_NUMBER  \
# 0           198       Donald     OConnell      DOCONNEL  650.507.9833
# 1           199      Douglas        Grant        DGRANT  650.507.9844
# 2           200     Jennifer       Whalen       JWHALEN  515.123.4444
# 3           201      Michael    Hartstein      MHARTSTE  515.123.5555
# 4           202          Pat          Fay          PFAY  603.123.6666
# 5           203        Susan       Mavris       SMAVRIS  515.123.7777
# 6           204      Hermann         Baer         HBAER  515.123.8888
# 7           205      Shelley      Higgins      SHIGGINS  515.123.8080
# 8           206      William        Gietz        WGIETZ  515.123.8181
# 9           100       Steven         King         SKING  515.123.4567
# 10          101            0            0  515.123.4568     21-SEP-05
# 11          102          Lex      De Haan       LDEHAAN  515.123.4569
# ...

# %%
df['NewFName']=df['FIRST_NAME'].fillna("Alex")
df.head(5)
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID  NewFName
# 0  SH_CLERK   2600             -         124           50.0    Donald
# 1  SH_CLERK   2600             -         124           50.0   Douglas
# 2   AD_ASST   4400             -         101           10.0  Jennifer
# 3    MK_MAN  13000             -         100           20.0   Michael
# 4    MK_REP   6000             -         201           20.0       Pat

# %%
df.isnull().sum()
# Out:
# EMPLOYEE_ID       0
# FIRST_NAME        2
# LAST_NAME         4
# EMAIL             0
# PHONE_NUMBER      1
# HIRE_DATE         0
# JOB_ID            0
# SALARY            0
# COMMISSION_PCT    0
# MANAGER_ID        1
# DEPARTMENT_ID     2
# NewFName          0
# dtype: int64

# %%
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME         EMAIL  PHONE_NUMBER  \
# 0           198       Donald     OConnell      DOCONNEL  650.507.9833
# 1           199      Douglas        Grant        DGRANT  650.507.9844
# 2           200     Jennifer       Whalen       JWHALEN  515.123.4444
# 3           201      Michael    Hartstein      MHARTSTE  515.123.5555
# 4           202          Pat          Fay          PFAY  603.123.6666
# 5           203        Susan       Mavris       SMAVRIS  515.123.7777
# 6           204      Hermann         Baer         HBAER  515.123.8888
# 7           205      Shelley      Higgins      SHIGGINS  515.123.8080
# 8           206      William        Gietz        WGIETZ  515.123.8181
# 9           100       Steven         King         SKING  515.123.4567
# 10          101          NaN          NaN  515.123.4568     21-SEP-05
# 11          102          Lex      De Haan       LDEHAAN  515.123.4569
# ...

# %%
df.isnull().sum()
df['NewLName']=df['LAST_NAME'].fillna("Jaiswal")
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME         EMAIL  PHONE_NUMBER  \
# 0           198       Donald     OConnell      DOCONNEL  650.507.9833
# 1           199      Douglas        Grant        DGRANT  650.507.9844
# 2           200     Jennifer       Whalen       JWHALEN  515.123.4444
# 3           201      Michael    Hartstein      MHARTSTE  515.123.5555
# 4           202          Pat          Fay          PFAY  603.123.6666
# 5           203        Susan       Mavris       SMAVRIS  515.123.7777
# 6           204      Hermann         Baer         HBAER  515.123.8888
# 7           205      Shelley      Higgins      SHIGGINS  515.123.8080
# 8           206      William        Gietz        WGIETZ  515.123.8181
# 9           100       Steven         King         SKING  515.123.4567
# 10          101          NaN          NaN  515.123.4568     21-SEP-05
# 11          102          Lex      De Haan       LDEHAAN  515.123.4569
# ...

# %%
#Renaming Column
df=df.rename(columns={'HIRE_DATE':'JOINED_Date'})
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME         EMAIL  PHONE_NUMBER  \
# 0           198       Donald     OConnell      DOCONNEL  650.507.9833
# 1           199      Douglas        Grant        DGRANT  650.507.9844
# 2           200     Jennifer       Whalen       JWHALEN  515.123.4444
# 3           201      Michael    Hartstein      MHARTSTE  515.123.5555
# 4           202          Pat          Fay          PFAY  603.123.6666
# 5           203        Susan       Mavris       SMAVRIS  515.123.7777
# 6           204      Hermann         Baer         HBAER  515.123.8888
# 7           205      Shelley      Higgins      SHIGGINS  515.123.8080
# 8           206      William        Gietz        WGIETZ  515.123.8181
# 9           100       Steven         King         SKING  515.123.4567
# 10          101          NaN          NaN  515.123.4568     21-SEP-05
# 11          102          Lex      De Haan       LDEHAAN  515.123.4569
# ...
