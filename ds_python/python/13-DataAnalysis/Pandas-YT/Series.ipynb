# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
my_list=[10,20,30]
print(pd.Series(data=my_list),"with default index")
pd.Series(index=labels,data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64 with default index
# a    10
# b    20
# c    30
# dtype: int64

# %%
d={"a":2,"b":3}
pd.Series(d)
# Out:
# a    2
# b    3
# dtype: int64
